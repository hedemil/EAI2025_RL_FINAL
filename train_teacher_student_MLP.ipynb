# %% [markdown]
# # Teacher-Student Training Script
#
# (In progress)

# %%
#!/usr/bin/env python3
"""Visualization script for Go1 with height scanner."""
import os
import subprocess
# Tell XLA to use Triton GEMM
xla_flags = os.environ.get('XLA_FLAGS', '')
xla_flags += ' --xla_gpu_triton_gemm_any=True'
os.environ['XLA_FLAGS'] = xla_flags
os.environ['MUJOCO_GL'] = 'egl'

import jax
import jax.numpy as jp
from brax.training.agents.ppo import networks as ppo_networks
from brax.training.agents.ppo import losses as ppo_losses

import mujoco
from mujoco_playground import wrapper
from mujoco_playground import registry
from mujoco_playground.config import locomotion_params
from custom_env import Joystick, default_config

from datetime import datetime
import mediapy as media
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import cv2
import functools
from io import BytesIO
from PIL import Image, ImageDraw, ImageFont
from IPython.display import Image as IPyimage, display, HTML, clear_output

from utils import render_video_during_training, evaluate_policy

scene_option = mujoco.MjvOption()
scene_option.geomgroup[2] = True   # Show visual geoms
scene_option.geomgroup[3] = False  # Hide collision geoms
scene_option.geomgroup[5] = True   # Show sites (including height scanner visualization)
scene_option.flags[mujoco.mjtVisFlag.mjVIS_CONTACTPOINT] = True  # Show contact points
scene_option.flags[mujoco.mjtVisFlag.mjVIS_RANGEFINDER] = True
print("Creating Visualization...")

xml_path = 'custom_env.xml' # 'custom_env_debug_wall.xml'
env = Joystick(xml_path=xml_path, config=default_config())

# JIT compile the functions for speed
jit_reset = jax.jit(env.reset)
jit_step = jax.jit(env.step)
jit_terrain_height = jax.jit(env._get_torso_terrain_height)

seed = 1234
num_envs = ()
key = jax.random.PRNGKey(seed)
key, key_env, eval_key, key_policy, key_value = jax.random.split(key, 5)
key_envs = jax.random.split(key_env, num_envs)
env_state = jit_reset(key_envs)
# Out:
# Creating Visualization...
# 2025-10-03 15:08:31.934176: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.

# %% [markdown]
# # Teacher Policy
#
# - pretrained inside train.ipynb
# - we want to load the parameters
#
# - Inputs: privileged_state with heightmap
# - Output: action

# %% [markdown]
# ### Load parameters for pre-trained teacher

# %%
from brax.training.agents.ppo import networks as ppo_networks
from brax.training.agents.ppo import losses as ppo_losses
from brax.training.acme import running_statistics


# Needs to match training
obs_shape = (96,)
action_size = env.action_size

# Observation normalisation
loaded_params = np.load("params.npy", allow_pickle=True)
normalizer_params = loaded_params[0]  
normalize = running_statistics.normalize

# Setup
ppo_params = locomotion_params.brax_ppo_config('Go1JoystickRoughTerrain')
network_factory = ppo_networks.make_ppo_networks
if "network_factory" in ppo_params:
    network_factory = functools.partial(
        ppo_networks.make_ppo_networks,
        **ppo_params.network_factory
    )

ppo_network = network_factory(
    obs_shape, action_size, preprocess_observations_fn=normalize
)

init_params = ppo_losses.PPONetworkParams(
    policy=ppo_network.policy_network.init(key_policy),
    value=ppo_network.value_network.init(key_value),
)

# Create policy function
make_policy = ppo_networks.make_inference_fn(ppo_network)

params = np.load("params.npy", allow_pickle=True)

jit_inference_fn   = jax.jit(make_policy(params, deterministic=True))

# %% [markdown]
# # Training
#
# - Teacher is run for one episode at a time with privileged observations
# - Non-priveleged observations are saved as student input
# - action distribution (logits) are saved as student targets
# - RNN is trained with data from episode

# %%
from custom_ppo_train import _maybe_wrap_env

seed = 42

action_size = 12
hidden_size = 64

episodes = 1 # preivously 1000
envs_per_episode = 1
episode_length = 128 # preivously 1024
action_repeat = 1

learning_rate = 1e-4 # preivously 1e-5

teacher_visualisation = False

# %% [markdown]
# # Student Policy
#
# Experiment 1: training with a newly initialized LSTM for a Recurrent Neural Network

# %%
# Policy Definition
import jax.numpy as jnp
import jax
import flax.linen as nn
import optax

class StudentPolicy(nn.Module):
    """Feedforward student policy that mimics teacher's action distribution"""
    action_size: int
    hidden_size: int   # Number of units in the hidden layer
    
    @nn.compact
    def __call__(self, x):
        # x shape: (batch_size, obs_dim)
        
        # First dense layer with activation
        x = nn.Dense(self.hidden_size)(x)
        x = nn.relu(x)  # or use nn.tanh(x) if preferred

        # Second dense layer to output logits (actions + log_stds)
        logits = nn.Dense(features=2 * self.action_size)(x)
        
        return logits

# Initialize student network
student_obs_dim = 52
batch_size = 128
episode_length = 1024
batches = episode_length // batch_size

# Create student network
student_net = StudentPolicy(action_size = action_size, hidden_size = hidden_size)

# Initialize with dummy data
dummy_input = jnp.ones((batch_size, student_obs_dim))
key_student = jax.random.PRNGKey(42)
student_params = student_net.init(key_student, dummy_input)

print(f"Student network initialized!")
print(f"Input shape: {dummy_input.shape}")
print(f"Expected output shape: (batch_size, 24) for logits")

# Test student network
test_output = student_net.apply(student_params, dummy_input)
print(f"Test output shape: {test_output.shape}")
# Out:
# 2025-10-03 15:09:04.578206: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2025-10-03 15:09:05.613096: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# Student network initialized!
# Input shape: (128, 52)
# Expected output shape: (batch_size, 24) for logits
# Test output shape: (128, 24)

# %% [markdown]
# # Helper Functions for Teacher-Student Training
# Define the functions needed to extract logits from the teacher network.

# %%
# Function to get logits from teacher network
@jax.jit
def get_teacher_logits(params, observations):
    param_subset = (params[0], params[1])  # normalizer and policy params
    return ppo_network.policy_network.apply(*param_subset, observations)

# Training setup
optimizer = optax.adam(learning_rate)
opt_state = optimizer.init(student_params)

# Training function
@jax.jit
def train_step(params, opt_state, inputs, targets):
    def loss_fn(params):
        predictions = student_net.apply(params, inputs)
        loss = jnp.mean((predictions - targets) ** 2)
        return loss
    
    loss, grads = jax.value_and_grad(loss_fn)(params)
    updates, opt_state = optimizer.update(grads, opt_state, params)
    params = optax.apply_updates(params, updates)
    return params, opt_state, loss

# %% [markdown]
# ## Training Loop

# %%
from mujoco_playground._src.gait import draw_joystick_command
env_cfg = default_config()
env_cfg.pert_config.enable = True
env_cfg.pert_config.velocity_kick = [0.0, 0.0]
env_cfg.pert_config.kick_wait_times = [5.0, 15.0]
env_cfg.command_config.a = [1.5, 0.8, 2*jp.pi]


# Loop over episodes
training_losses = []
test_losses = []
for episode in range(episodes):
    print(f"\n Episode {episode + 1}/{episodes} ")
    
    key = jax.random.PRNGKey(seed + episode)
    key, key_env, eval_key, key_policy, key_value = jax.random.split(key, 5)

    wrapper_env = _maybe_wrap_env(
        env,
        wrap_env=True,
        num_envs=envs_per_episode,
        episode_length=episode_length,
        action_repeat=action_repeat,
        key_env=key_env,
    )

    # Reset environment 
    reset_fn = jax.jit(env.reset)
    key_envs = jax.random.split(key_env, num_envs)
    env_state = reset_fn(key_envs)

    rng = jax.random.PRNGKey(episode)
    # raw_command = jax.random.uniform(rng, shape=(3), minval=0.0, maxval=1.0)
    raw_command = jp.array([0.5, 0.0, 0.0]) 

    command = jp.array([
        raw_command[0] * env_cfg.command_config.a[0], 
        raw_command[1] * env_cfg.command_config.a[1],
        raw_command[2] * env_cfg.command_config.a[2] 
    ])
    state = jit_reset(rng)
    state.info["command"] = command

    # Visualisation storing
    rollout = []
    modify_scene_fns = []

    # Training data storing
    student_inputs = []
    student_targets = []
    
    for step in range(episode_length):
        # Get teacher action and logits
        act_rng, rng = jax.random.split(rng)
        ctrl, actions = jit_inference_fn(state.obs, act_rng)
        print(f"control after inference: {ctrl}")

        # postprocessed_actions, out_dict = jit_test_inference(state.obs, act_rng)
        # print(f"postprocessed: {postprocessed_actions}\nlog_prob: {out_dict['log_prob']}\nraw_action: {out_dict['raw_action']}")

        # Get teacher logits (distribution parameters)
        param_subset = (params[0], params[1])
        logits = ppo_network.policy_network.apply(*param_subset, state.obs)

        # TO TEST IF CONVERSION WORKS
        # Convert logits to action
        parametric_action_distribution = ppo_network.parametric_action_distribution
        # raw_action = parametric_action_distribution.sample_no_postprocessing(logits, rng)
        # ctrl = parametric_action_distribution.postprocess(raw_action)

        ctrl = parametric_action_distribution.mode(logits)

        print(f"control after conversion back and fourth: {ctrl}")


        

        # print(f"logits: {logits}\nshape: {logits.shape}")
        
        # Store data for student training
        student_inputs.append(state.obs['state'])  # Non-privileged observations
        student_targets.append(logits)  # Teacher's action distribution logits
        
        # Step environment
        state = jit_step(state, ctrl)
        state.info["command"] = command
        
        # Visualization data
        rollout.append(state)
        xyz = np.array(state.data.xpos[env._torso_body_id])
        xyz += np.array([0, 0, 0.2])
        x_axis = state.data.xmat[env._torso_body_id, 0]
        yaw = -np.arctan2(x_axis[1], x_axis[0])
        modify_scene_fns.append(
            functools.partial(
                draw_joystick_command,
                cmd=state.info["command"],
                xyz=xyz,
                theta=yaw,
                scl=abs(state.info["command"][0]) / env_cfg.command_config.a[0],
            )
        )

    # Prepare training data
    student_inputs_array = jnp.array(student_inputs)  # (1024, 52)
    student_targets_array = jnp.array(student_targets)  # (1024, 24)
        
    # Train student
    total_loss = 0
    for batch_idx in range(batches):
        start_idx = batch_idx * batch_size
        end_idx = start_idx + batch_size
        
        batch_inputs = student_inputs_array[start_idx:end_idx]
        batch_targets = student_targets_array[start_idx:end_idx]
        
        student_params, opt_state, loss = train_step(
            student_params, opt_state, batch_inputs, batch_targets
        )
        total_loss += loss
    training_losses.append(total_loss / batches)

    # Optional visualization
    if teacher_visualisation: 
        render_every = 2
        fps = 1.0 / env.dt / render_every
        traj = rollout[::render_every]
        mod_fns = modify_scene_fns[::render_every]

        scene_option = mujoco.MjvOption()
        scene_option.geomgroup[2] = True
        scene_option.geomgroup[3] = False
        scene_option.flags[mujoco.mjtVisFlag.mjVIS_CONTACTPOINT] = True
        scene_option.flags[mujoco.mjtVisFlag.mjVIS_TRANSPARENT] = False
        scene_option.flags[mujoco.mjtVisFlag.mjVIS_PERTFORCE] = True

        frames = env.render(
            traj,
            camera="track",
            scene_option=scene_option,
            width=640,
            height=480,
            modify_scene_fns=mod_fns,
        )   
        media.show_video(frames, fps=fps)
# Out:
#  Episode 1/1
# control after inference: [ 0.26770803 -0.2526175   0.29891846 -0.39343902 -0.74224794  0.38540024
#   0.00209175 -0.341974   -0.00231108 -0.11269499 -0.24127516  0.04868865]
# control after conversion back and fourth: [ 0.26770806 -0.25261754  0.29891843 -0.39343902 -0.74224794  0.38540012
#   0.00209174 -0.341974   -0.00231108 -0.11269496 -0.24127516  0.04868871]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/jovyan/EAI2025_RL_FINAL/train_teacher_student_MLP.ipynb Cell 13 line 8
#      <a href='vscode-notebook-cell://gpu1.eecs.kth.se/home/jovyan/EAI2025_RL_FINAL/train_teacher_student_MLP.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=81'>82</a> student_targets.append(logits)  # Teacher's action distribution logits
#      <a href='vscode-notebook-cell://gpu1.eecs.kth.se/home/jovyan/EAI2025_RL_FINAL/train_teacher_student_MLP.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=83'>84</a> # Step environment
# ---> <a href='vscode-notebook-cell://gpu1.eecs.kth.se/home/jovyan/EAI2025_RL_FINAL/train_teacher_student_MLP.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=84'>85</a> state = jit_step(state, ctrl)
#      <a href='vscode-notebook-cell://gpu1.eecs.kth.se/home/jovyan/EAI2025_RL_FINAL/train_teacher_student_MLP.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=85'>86</a> state.info["command"] = command
#      <a href='vscode-notebook-cell://gpu1.eecs.kth.se/home/jovyan/EAI2025_RL_FINAL/train_teacher_student_MLP.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=87'>88</a> # Visualization data
#
#     [... skipping hidden 1 frame]
#
# File ~/eai2025_rl_final/venv_rl/lib/python3.10/site-packages/jax/_src/pjit.py:292, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     287 if config.no_tracing.value:
#     288   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     289                      "`jit`, but 'no_tracing' is set")
#     291 (outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked, box_data,
# --> 292  executable, pgle_profiler) = _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     294 maybe_fastpath_data = _get_fastpath_data(
#     295     executable, out_tree, args_flat, out_flat, attrs_tracked, box_data,
#     296     jaxpr.effects, jaxpr.consts, jit_info.abstracted_axes, pgle_profiler)
#     298 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/eai2025_rl_final/venv_rl/lib/python3.10/site-packages/jax/_src/pjit.py:153, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     151   args_flat = map(core.full_lower, args_flat)
#     152   core.check_eval_args(args_flat)
# --> 153   out_flat, compiled, profiler = _pjit_call_impl_python(*args_flat, **p.params)
#     154 else:
#     155   out_flat = pjit_p.bind(*args_flat, **p.params)
#
# File ~/eai2025_rl_final/venv_rl/lib/python3.10/site-packages/jax/_src/pjit.py:1855, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *args)
#    1843 compiler_options_kvs = compiler_options_kvs + tuple(pgle_compile_options.items())
#    1844 # Passing mutable PGLE profile here since it should be extracted by JAXPR to
#    1845 # initialize the fdo_profile compile option.
#    1846 compiled = _resolve_and_lower(
#    1847     args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1848     out_shardings=out_shardings, in_layouts=in_layouts,
#    1849     out_layouts=out_layouts, donated_invars=donated_invars,
#    1850     ctx_mesh=ctx_mesh, name=name, keep_unused=keep_unused,
#    1851     inline=inline, lowering_platforms=None,
#    1852     lowering_parameters=mlir.LoweringParameters(),
#    1853     pgle_profiler=pgle_profiler,
#    1854     compiler_options_kvs=compiler_options_kvs,
# -> 1855 ).compile()
#    1857 # This check is expensive so only do it if enable_checks is on.
#    1858 if compiled._auto_spmd_lowering and config.enable_checks.value:
#
# File ~/eai2025_rl_final/venv_rl/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:2410, in MeshComputation.compile(self, compiler_options)
#    2408 compiler_options_kvs = self._compiler_options_kvs + t_compiler_options
#    2409 if self._executable is None or compiler_options_kvs:
# -> 2410   executable = UnloadedMeshExecutable.from_hlo(
#    2411       self._name, self._hlo, **self.compile_args,
#    2412       compiler_options_kvs=compiler_options_kvs)
#    2413   if not compiler_options_kvs:
#    2414     self._executable = executable
#
# File ~/eai2025_rl_final/venv_rl/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:2952, in UnloadedMeshExecutable.from_hlo(***failed resolving arguments***)
#    2949       break
#    2951 util.test_event("pxla_cached_compilation")
# -> 2952 xla_executable = _cached_compilation(
#    2953     hlo, name, mesh, spmd_lowering,
#    2954     tuple_args, auto_spmd_lowering, allow_prop_to_inputs,
#    2955     allow_prop_to_outputs, tuple(host_callbacks), backend, da, pmap_nreps,
#    2956     compiler_options_kvs, pgle_profiler)
#    2958 if auto_spmd_lowering:
#    2959   assert mesh is not None
#
# File ~/eai2025_rl_final/venv_rl/lib/python3.10/site-packages/jax/_src/interpreters/pxla.py:2743, in _cached_compilation(computation, name, mesh, spmd_lowering, tuple_args, auto_spmd_lowering, allow_prop_to_inputs, allow_prop_to_outputs, host_callbacks, backend, da, pmap_nreps, compiler_options_kvs, pgle_profiler)
#    2735 compile_options = create_compile_options(
#    2736     computation, mesh, spmd_lowering, tuple_args, auto_spmd_lowering,
#    2737     allow_prop_to_inputs, allow_prop_to_outputs, backend,
#    2738     dev, pmap_nreps, compiler_options)
#    2740 with dispatch.log_elapsed_time(
#    2741     "Finished XLA compilation of {fun_name} in {elapsed_time:.9f} sec",
#    2742     fun_name=name, event=dispatch.BACKEND_COMPILE_EVENT):
# -> 2743   xla_executable = compiler.compile_or_get_cached(
#    2744       backend, computation, dev, compile_options, host_callbacks,
#    2745       da, pgle_profiler)
#    2746 return xla_executable
#
# File ~/eai2025_rl_final/venv_rl/lib/python3.10/site-packages/jax/_src/compiler.py:500, in compile_or_get_cached(backend, computation, devices, compile_options, host_callbacks, executable_devices, pgle_profiler)
#     498 else:
#     499   log_persistent_cache_miss(module_name, cache_key)
# --> 500   return _compile_and_write_cache(
#     501       backend,
#     502       computation,
#     503       executable_devices,
#     504       compile_options,
#     505       host_callbacks,
#     506       module_name,
#     507       cache_key,
#     508   )
#
# File ~/eai2025_rl_final/venv_rl/lib/python3.10/site-packages/jax/_src/compiler.py:768, in _compile_and_write_cache(backend, computation, executable_devices, compile_options, host_callbacks, module_name, cache_key)
#     758 def _compile_and_write_cache(
#     759     backend: xc.Client,
#     760     computation: ir.Module,
#    (...)
#     765     cache_key: str,
#     766 ) -> xc.LoadedExecutable:
#     767   start_time = time.monotonic()
# --> 768   executable = backend_compile_and_load(
#     769       backend, computation, executable_devices, compile_options, host_callbacks
#     770   )
#     771   compile_time = time.monotonic() - start_time
#     772   _cache_write(
#     773       cache_key, compile_time, module_name, backend, executable, host_callbacks
#     774   )
#
# File ~/eai2025_rl_final/venv_rl/lib/python3.10/site-packages/jax/_src/profiler.py:354, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     351 @wraps(func)
#     352 def wrapper(*args, **kwargs):
#     353   with TraceAnnotation(name, **decorator_kwargs):
# --> 354     return func(*args, **kwargs)
#
# File ~/eai2025_rl_final/venv_rl/lib/python3.10/site-packages/jax/_src/compiler.py:385, in backend_compile_and_load(backend, module, executable_devices, options, host_callbacks)
#     376       return backend.compile_and_load(
#     377           built_c,
#     378           executable_devices=executable_devices,
#     379           compile_options=options,
#     380           host_callbacks=host_callbacks,
#     381       )
#     382     # Some backends don't have `host_callbacks` option yet
#     383     # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     384     # to take in `host_callbacks`
# --> 385     return backend.compile_and_load(
#     386         built_c,
#     387         executable_devices=executable_devices,
#     388         compile_options=options,
#     389     )
#     390 except xc.XlaRuntimeError as e:
#     391   for error_handler in _XLA_RUNTIME_ERROR_HANDLERS:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Plot training metrics

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(range(1, len(training_losses) + 1), training_losses)
plt.xlabel("Episode")
plt.ylabel("MSE Loss")
plt.legend(("Training Loss"))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/jovyan/EAI2025_RL_FINAL/train_teacher_student_MLP.ipynb Cell 15 line 4
#       <a href='vscode-notebook-cell://gpu1.eecs.kth.se/home/jovyan/EAI2025_RL_FINAL/train_teacher_student_MLP.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell://gpu1.eecs.kth.se/home/jovyan/EAI2025_RL_FINAL/train_teacher_student_MLP.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> plt.figure(figsize=(12,6))
# ----> <a href='vscode-notebook-cell://gpu1.eecs.kth.se/home/jovyan/EAI2025_RL_FINAL/train_teacher_student_MLP.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> plt.plot(range(1, len(training_losses) + 1), training_losses)
#       <a href='vscode-notebook-cell://gpu1.eecs.kth.se/home/jovyan/EAI2025_RL_FINAL/train_teacher_student_MLP.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> plt.xlabel("Episode")
#       <a href='vscode-notebook-cell://gpu1.eecs.kth.se/home/jovyan/EAI2025_RL_FINAL/train_teacher_student_MLP.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> plt.ylabel("MSE Loss")
#
# NameError: name 'training_losses' is not defined

# %% [markdown]
# ## Save RNN

# %%
# Save student RNN parameters
import pickle

# Save
with open('student_params_MLP.pkl', 'wb') as f:
    pickle.dump(student_params, f)
print("Student saved to student_params_MLP.pkl")
# Out:
# Student RNN saved to student_params.pkl

# %% [markdown]
# ### (OPTIONAL): Load Trained RNN

# %%
import pickle
# Load student RNN parameters
with open('student_params_MLP.pkl', 'rb') as f:
    student_params = pickle.load(f)
print("Student loaded from student_params_MLP.pkl")
# Out:
# Student loaded from student_params_MLP.pkl

# %% [markdown]
# ## Evaluate Student Polcicy

# %% [markdown]
# ### Evaluation Environment Config

# %%
# Env config
student_env_cfg = default_config()
student_env_cfg.pert_config.enable = True
student_env_cfg.pert_config.velocity_kick = [0.0, 0.0]
student_env_cfg.pert_config.kick_wait_times = [5.0, 15.0]
student_env_cfg.command_config.a = [1.5, 0.8, 2*jp.pi] # Max command values





seed = 42

num_episodes = 5
episode_length = 100 # previously 500

# %%
# Student eval
from mujoco_playground._src.gait import draw_joystick_command

for episode in range(num_episodes):
    key = jax.random.PRNGKey(episode + seed)
    key, key_env, eval_key, key_policy, key_value = jax.random.split(key, 5)

    wrapper_env = _maybe_wrap_env(
    env,
    wrap_env = True,
    num_envs = 1,
    episode_length = episode_length,
    action_repeat = 1,
    key_env = key_env,
    )

    # Reset environment 
    reset_fn = jax.jit(env.reset)
    key_envs = jax.random.split(key_env, num_envs)
    env_state = reset_fn(key_envs)

    
    # Set commands 
    rng = jax.random.PRNGKey(episode)
    # raw_command = jax.random.uniform(rng, shape=(3), minval=0.0, maxval=1.0)
    raw_command = jp.array([0.5, 0.0, 0.0])  # Hard coded for testing

    command = jp.array([
        raw_command[0] * student_env_cfg.command_config.a[0], 
        raw_command[1] * student_env_cfg.command_config.a[1],
        raw_command[2] * student_env_cfg.command_config.a[2] 
    ])
    state = jit_reset(rng)
    state.info["command"] = command

    # Visualisation storing
    rollout = []
    modify_scene_fns = []

    for step in range(episode_length):
        # feed non-priveleged observations to network
        student_obs = state.obs['state'] 

        # Get student logits from RNN 
        student_obs_batch = student_obs[:student_obs_dim].reshape(1, -1)
        logits = student_net.apply(student_params, student_obs_batch).squeeze(0) 

        # Convert logits to action
        parametric_action_distribution = ppo_network.parametric_action_distribution
        # raw_action = parametric_action_distribution.sample_no_postprocessing(logits, rng)
        # ctrl = parametric_action_distribution.postprocess(raw_action)

        ctrl = parametric_action_distribution.mode(logits)

        # Take step
        state = jit_step(state, ctrl)
        state.info["command"] = command

        # Visualization magic
        rollout.append(state)
        xyz = np.array(state.data.xpos[env._torso_body_id])
        xyz += np.array([0, 0, 0.2])
        x_axis = state.data.xmat[env._torso_body_id, 0]
        yaw = -np.arctan2(x_axis[1], x_axis[0])
        modify_scene_fns.append(
            functools.partial(
                draw_joystick_command,
                cmd=state.info["command"],
                xyz=xyz,
                theta=yaw,
                scl=abs(state.info["command"][0]) / student_env_cfg.command_config.a[0],
            )
        )

    # Display visualisation magic
    render_every = 2
    fps = 1.0 / env.dt / render_every
    traj = rollout[::render_every]
    mod_fns = modify_scene_fns[::render_every]

    scene_option = mujoco.MjvOption()
    scene_option.geomgroup[2] = True
    scene_option.geomgroup[3] = False
    scene_option.flags[mujoco.mjtVisFlag.mjVIS_CONTACTPOINT] = True
    scene_option.flags[mujoco.mjtVisFlag.mjVIS_TRANSPARENT] = False
    scene_option.flags[mujoco.mjtVisFlag.mjVIS_PERTFORCE] = True

    frames = env.render(
        traj,
        camera="track",
        scene_option=scene_option,
        width=640,
        height=480,
        modify_scene_fns=mod_fns,
    )   
    media.show_video(frames, fps=fps)
# Out:
# 100%|██████████| 50/50 [00:09<00:00,  5.04it/s]
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="640" height="480" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>
# 100%|██████████| 50/50 [00:10<00:00,  4.77it/s]
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="640" height="480" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>
# 100%|██████████| 50/50 [00:10<00:00,  4.95it/s]
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="640" height="480" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>
# 100%|██████████| 50/50 [00:09<00:00,  5.01it/s]
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="640" height="480" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>
# 100%|██████████| 50/50 [00:10<00:00,  4.99it/s]
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="640" height="480" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>
